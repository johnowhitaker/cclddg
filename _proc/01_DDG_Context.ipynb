# %% [raw]
# ---
# description: Managing admin around the DDG training and sampling process.
# output-file: ddg_context.html
# title: Denoising Diffusion GAN Context
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| include: false
from nbdev.showdoc import *

# %%
#|output: asis
#| echo: false
show_doc(DDG_Context)
# Out:
# ---
#
# [source](https://github.com/johnowhitaker/cclddg/tree/master/blob/master/cclddg/ddg_context.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### DDG_Context
#
# >      DDG_Context (n_steps=5, beta_min=0.3, beta_max=0.9, device='cpu')
#
# Keep track of the numbre of steps, variance schedule etc. And provide a few utility functions.

# %% [markdown]
# Included functions:

# %%
#|output: asis
#| echo: false
show_doc(DDG_Context.q_xt_xtminus1)
# Out:
# ---
#
# [source](https://github.com/johnowhitaker/cclddg/tree/master/blob/master/cclddg/ddg_context.py#L24){target="_blank" style="float:right; font-size:smaller"}
#
# ### DDG_Context.q_xt_xtminus1
#
# >      DDG_Context.q_xt_xtminus1 (xtm1, t)
#
# A single noising step.

# %%
#|output: asis
#| echo: false
show_doc(DDG_Context.q_xt_x0)
# Out:
# ---
#
# [source](https://github.com/johnowhitaker/cclddg/tree/master/blob/master/cclddg/ddg_context.py#L31){target="_blank" style="float:right; font-size:smaller"}
#
# ### DDG_Context.q_xt_x0
#
# >      DDG_Context.q_xt_x0 (x0, t)
#
# Jump to a given step.

# %%
#|output: asis
#| echo: false
show_doc(DDG_Context.p_xt)
# Out:
# ---
#
# [source](https://github.com/johnowhitaker/cclddg/tree/master/blob/master/cclddg/ddg_context.py#L38){target="_blank" style="float:right; font-size:smaller"}
#
# ### DDG_Context.p_xt
#
# >      DDG_Context.p_xt (xt, noise, t)
#
# The reverse step, not used in DDG but included for vanilla diffusion tests.

# %%
#|output: asis
#| echo: false
show_doc(DDG_Context.examples)
# Out:
# ---
#
# [source](https://github.com/johnowhitaker/cclddg/tree/master/blob/master/cclddg/ddg_context.py#L52){target="_blank" style="float:right; font-size:smaller"}
#
# ### DDG_Context.examples
#
# >      DDG_Context.examples (ae_model, unet, cloob, n_examples=12,
# >                            cfg_scale_min=0, cfg_scale_max=4, prompts=['A
# >                            photograph portrait of a man with a beard, a human
# >                            face', 'Green hills and grass beneath a blue sky',
# >                            'A watercolor painting of an underwater submarine',
# >                            'A car, a photo of a red car', 'An armchair in the
# >                            shape of an avocado', 'blue ocean waves', 'A red
# >                            stop sign'], img_size=128, z_dim=8)
#
# Given ae_model, a u_net and cloob, produce some example images with CFG.

# %% [markdown]
# In action:

# %%
ddg = DDG_Context()
x0 = torch.randn(8, 4, 16, 16)
t = torch.randint(0, 4, (8,), dtype=torch.long)
x_t, n_t = ddg.q_xt_x0(x0, t)
x_t.shape, n_t.shape
# Out:
# (torch.Size([8, 4, 16, 16]), torch.Size([8, 4, 16, 16]))

# %%
# TODO: return noise optional
# TODO: explain what this is :)

# %%
# TODO random t convenience function
# TODO p_xt_xtm1 for non-DDG diffusion
